# %%
import pandas as pd
from mdalgos.algos import *

# %%
ts = pd.read_csv('Euro_pfund.csv')
ts
# Out:
#                t  Euro_Pfund
# 0     1999-01-04     0.71110
# 1     1999-01-05     0.71220
# 2     1999-01-06     0.70760
# 3     1999-01-07     0.70585
# 4     1999-01-08     0.70940
# ...          ...         ...
# 5895  2022-01-10     0.83398
# 5896  2022-01-11     0.83475
# 5897  2022-01-12     0.83338
# 5898  2022-01-13     0.83545
# 5899  2022-01-14     0.83508
#
# [5900 rows x 2 columns]

# %%
mkal(ts, path='/home/qijiajun/motifs/')

# %%
grammarintroduction(ts, path='/home/qijiajun/motifs/')

# %%
stomp(ts, path='/home/qijiajun/motifs/')

# %%
scrimp_2plus(ts, path='/home/qijiajun/motifs/')

# %%
stump(ts, path='/home/qijiajun/motifs/')

# %%
gpu_stump(ts, path= '/home/qijiajun/motifs/')
